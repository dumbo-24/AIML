# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
import pandas as pd
data = {"Country":["Brazil", "Russia", "India", "China", "South Africa"],
         "Capital":["Brasilia", "scow", "How Delhi", "Beijing", "Pretoria"],
         "Area":[6.516,17.10,1.286,9.557,1.221],
         "Population":[200.4,143.5,1252,1757,52.96]}


data_table = pd.DataFrame(data)
print(data_table)
# Out:
#         Country    Capital    Area  Population
# 0        Brazil   Brasilia   6.516      200.40
# 1        Russia       scow  17.100      143.50
# 2         India  How Delhi   1.286     1252.00
# 3         China    Beijing   9.557     1757.00
# 4  South Africa   Pretoria   1.221       52.96

# %%
x = np.linspace(0, 10, 100)

# %%
plt.plot(x, x, label ='linear')

# %%
plt.legend
# Out:
# <function matplotlib.pyplot.legend(*args, **kwargs) -> 'Legend'>
